# %%
import sys
import json


with open("../data/dog_breeds.jsonld", "r", encoding="utf-8") as f:
    data = json.load(f)

print("Type:", type(data))

if isinstance(data, list):
    print("First item:\n", data[0])
elif isinstance(data, dict):
    # some datasets are JSON-LD with '@graph'
    if "@graph" in data:
        print("First item in @graph:\n", data["@graph"][0])
    else:
        first_key = list(data.keys())[0]
        print(f"First key: {first_key}\nValue:\n", data[first_key])
# Out:
# Type: <class 'dict'>
# First key: @context
# Value:
#  https://schema.org/

# %%
if "@graph" in data:
    breeds = data["@graph"]
    print(f"Number of breeds: {len(breeds)}\n")

    # Print the first breed entry nicely
    print("First breed entry:\n")
    print(json.dumps(breeds[0], indent=2, ensure_ascii=False))

    # Just the name for quick check
    print("\nBreed name:", breeds[0].get("name"))
else:
    print("No '@graph' key found. Top-level keys:", data.keys())
# Out:
# No '@graph' key found. Top-level keys: dict_keys(['@context', '@type', '@id', 'name', 'description', 'url', 'inLanguage', 'isAccessibleForFree', 'dateCreated', 'dateModified', 'version', 'keywords', 'license', 'temporalCoverage', 'spatialCoverage', 'creator', 'publisher', 'publishingPrinciples', 'distribution', 'mainEntity', 'additionalProperty'])

# %%
print("Type of mainEntity:", type(data.get("mainEntity")))
print("Preview of mainEntity:\n")

import pprint
pprint.pprint(data.get("mainEntity"), depth=2, width=120)
# Out:
# Type of mainEntity: <class 'list'>
# Preview of mainEntity:
#
# [{'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/akita/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Akita',
#   'url': 'https://pawsomeauthority.com/dog-breeds/akita/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/american-cocker-spaniel/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'American Cocker Spaniel',
#   'url': 'https://pawsomeauthority.com/dog-breeds/american-cocker-spaniel/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/australian-cattle-dog/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Australian Cattle Dog',
#   'url': 'https://pawsomeauthority.com/dog-breeds/australian-cattle-dog/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/australian-shepherd/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Australian Shepherd',
#   'url': 'https://pawsomeauthority.com/dog-breeds/australian-shepherd/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/basset-hound/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Basset Hound',
#   'url': 'https://pawsomeauthority.com/dog-breeds/basset-hound/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/beagle/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Beagle',
#   'url': 'https://pawsomeauthority.com/dog-breeds/beagle/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/belgian-malinois/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Belgian Malinois',
#   'url': 'https://pawsomeauthority.com/dog-breeds/belgian-malinois/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/bernese-mountain-dog/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Bernese Mountain Dog',
#   'url': 'https://pawsomeauthority.com/dog-breeds/bernese-mountain-dog/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/bichon-frise/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Bichon Frisé',
#   'url': 'https://pawsomeauthority.com/dog-breeds/bichon-frise/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/bloodhound/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Bloodhound',
#   'url': 'https://pawsomeauthority.com/dog-breeds/bloodhound/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/border-collie/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Border Collie',
#   'url': 'https://pawsomeauthority.com/dog-breeds/border-collie/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/boston-terrier/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Boston Terrier',
#   'url': 'https://pawsomeauthority.com/dog-breeds/boston-terrier/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/boxer/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Boxer',
#   'url': 'https://pawsomeauthority.com/dog-breeds/boxer/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/brittany/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Brittany',
#   'url': 'https://pawsomeauthority.com/dog-breeds/brittany/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/bulldog/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Bulldog',
#   'url': 'https://pawsomeauthority.com/dog-breeds/bulldog/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/cane-corso/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Cane Corso',
#   'url': 'https://pawsomeauthority.com/dog-breeds/cane-corso/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/cavalier-king-charles-spaniel/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Cavalier King Charles Spaniel',
#   'url': 'https://pawsomeauthority.com/dog-breeds/cavalier-king-charles-spaniel/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/chesapeake-bay-retriever/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Chesapeake Bay Retriever',
#   'url': 'https://pawsomeauthority.com/dog-breeds/chesapeake-bay-retriever/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/chihuahua/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Chihuahua',
#   'url': 'https://pawsomeauthority.com/dog-breeds/chihuahua/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/collie/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Collie',
#   'url': 'https://pawsomeauthority.com/dog-breeds/collie/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/dachshund/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Dachshund',
#   'url': 'https://pawsomeauthority.com/dog-breeds/dachshund/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/dalmatian/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Dalmatian',
#   'url': 'https://pawsomeauthority.com/dog-breeds/dalmatian/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/doberman-pinscher/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Doberman Pinscher',
#   'url': 'https://pawsomeauthority.com/dog-breeds/doberman-pinscher/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/english-cocker-spaniel/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'English Cocker Spaniel',
#   'url': 'https://pawsomeauthority.com/dog-breeds/english-cocker-spaniel/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/english-springer-spaniel/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'English Springer Spaniel',
#   'url': 'https://pawsomeauthority.com/dog-breeds/english-springer-spaniel/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/french-bulldog/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'French Bulldog',
#   'url': 'https://pawsomeauthority.com/dog-breeds/french-bulldog/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/german-shepherd/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'German Shepherd',
#   'url': 'https://pawsomeauthority.com/dog-breeds/german-shepherd/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/german-shorthaired-pointer/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'German Shorthaired Pointer',
#   'url': 'https://pawsomeauthority.com/dog-breeds/german-shorthaired-pointer/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/giant-schnauzer/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Giant Schnauzer',
#   'url': 'https://pawsomeauthority.com/dog-breeds/giant-schnauzer/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/golden-retriever/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Golden Retriever',
#   'url': 'https://pawsomeauthority.com/dog-breeds/golden-retriever/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/great-dane/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Great Dane',
#   'url': 'https://pawsomeauthority.com/dog-breeds/great-dane/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/havanese/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Havanese',
#   'url': 'https://pawsomeauthority.com/dog-breeds/havanese/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/labrador-retriever/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Labrador Retriever',
#   'url': 'https://pawsomeauthority.com/dog-breeds/labrador-retriever/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/maltese/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Maltese',
#   'url': 'https://pawsomeauthority.com/dog-breeds/maltese/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/mastiff/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Mastiff',
#   'url': 'https://pawsomeauthority.com/dog-breeds/mastiff/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/miniature-american-shepherd/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Miniature American Shepherd',
#   'url': 'https://pawsomeauthority.com/dog-breeds/miniature-american-shepherd/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/miniature-poodle/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Miniature Poodle',
#   'url': 'https://pawsomeauthority.com/dog-breeds/miniature-poodle/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/miniature-schnauzer/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Miniature Schnauzer',
#   'url': 'https://pawsomeauthority.com/dog-breeds/miniature-schnauzer/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/newfoundland/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Newfoundland',
#   'url': 'https://pawsomeauthority.com/dog-breeds/newfoundland/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/papillon/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Papillon',
#   'url': 'https://pawsomeauthority.com/dog-breeds/papillon/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/pembroke-welsh-corgi/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Pembroke Welsh Corgi',
#   'url': 'https://pawsomeauthority.com/dog-breeds/pembroke-welsh-corgi/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/pomeranian/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Pomeranian',
#   'url': 'https://pawsomeauthority.com/dog-breeds/pomeranian/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/portuguese-water-dog/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Portuguese Water Dog',
#   'url': 'https://pawsomeauthority.com/dog-breeds/portuguese-water-dog/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/pug/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Pug',
#   'url': 'https://pawsomeauthority.com/dog-breeds/pug/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/rhodesian-ridgeback/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Rhodesian Ridgeback',
#   'url': 'https://pawsomeauthority.com/dog-breeds/rhodesian-ridgeback/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/rottweiler/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Rottweiler',
#   'url': 'https://pawsomeauthority.com/dog-breeds/rottweiler/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/saint-bernard/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Saint Bernard',
#   'url': 'https://pawsomeauthority.com/dog-breeds/saint-bernard/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/samoyed/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Samoyed',
#   'url': 'https://pawsomeauthority.com/dog-breeds/samoyed/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/shetland-sheepdog/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Shetland Sheepdog',
#   'url': 'https://pawsomeauthority.com/dog-breeds/shetland-sheepdog/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/shiba-inu/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Shiba Inu',
#   'url': 'https://pawsomeauthority.com/dog-breeds/shiba-inu/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/shih-tzu/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Shih Tzu',
#   'url': 'https://pawsomeauthority.com/dog-breeds/shih-tzu/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/siberian-husky/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Siberian Husky',
#   'url': 'https://pawsomeauthority.com/dog-breeds/siberian-husky/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/standard-poodle/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Standard Poodle',
#   'url': 'https://pawsomeauthority.com/dog-breeds/standard-poodle/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/toy-poodle/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Toy Poodle',
#   'url': 'https://pawsomeauthority.com/dog-breeds/toy-poodle/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/vizsla/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Vizsla',
#   'url': 'https://pawsomeauthority.com/dog-breeds/vizsla/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/weimaraner/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Weimaraner',
#   'url': 'https://pawsomeauthority.com/dog-breeds/weimaraner/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/west-highland-white-terrier/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'West Highland White Terrier',
#   'url': 'https://pawsomeauthority.com/dog-breeds/west-highland-white-terrier/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/whippet/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Whippet',
#   'url': 'https://pawsomeauthority.com/dog-breeds/whippet/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/wirehaired-pointing-griffon/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Wirehaired Pointing Griffon',
#   'url': 'https://pawsomeauthority.com/dog-breeds/wirehaired-pointing-griffon/profile/'},
#  {'@context': 'https://schema.org/',
#   '@id': 'https://pawsomeauthority.com/dog-breeds/yorkshire-terrier/profile/',
#   '@type': 'Thing',
#   'additionalProperty': [...],
#   'additionalType': 'https://schema.org/Animal',
#   'name': 'Yorkshire Terrier',
#   'url': 'https://pawsomeauthority.com/dog-breeds/yorkshire-terrier/profile/'}]

# %%
import json
import re

breeds_list = [
    "Labrador_Retriever",
    "German_Shepherd",
    "Golden_Retriever",
    "Boxer",
    "Beagle",
    "Pomeranian",
    "Siberian_Husky",
    "Doberman",
    "Shih-Tzu",
    "Yorkshire_Terrier",
]

# Normalize: lowercase, remove spaces, underscores, hyphens
def normalize(name):
    return re.sub(r"[-_\s]", "", name.lower())

target = {normalize(b): b for b in breeds_list}
found = []
missing = []

# Extract all breed names from JSON
json_breeds = [entry["name"] for entry in data["mainEntity"] if "name" in entry]

for breed_norm, orig in target.items():
    if any(normalize(name) == breed_norm for name in json_breeds):
        found.append(orig)
    else:
        missing.append(orig)

print("✅ Found in JSON:", found)
print("❌ Missing in JSON:", missing)
# Out:
# ✅ Found in JSON: ['Labrador_Retriever', 'German_Shepherd', 'Golden_Retriever', 'Boxer', 'Beagle', 'Pomeranian', 'Siberian_Husky', 'Shih-Tzu', 'Yorkshire_Terrier']
# ❌ Missing in JSON: ['Doberman']

# %%
import json
import re
from difflib import get_close_matches


entries = data.get("mainEntity", [])

# ---- Helpers ----
def normalize_basic(s: str) -> str:
    # lower, remove spaces/underscores/hyphens/punctuation
    return re.sub(r"[^a-z]", "", s.lower())

def normalize_doberman(s: str) -> str:
    s = s.lower()
    # unify common variants
    s = s.replace("dobermann", "doberman")
    s = s.replace("pinscher", "")  # allow matching 'doberman pinscher'
    # strip non-letters
    s = re.sub(r"[^a-z]", "", s)
    return s

# Target variants we want to catch
targets = {
    "doberman",
    "dobermanpinscher",   # exact phrase before stripping
    "dobermann",
}

# ---- Exact-ish search with smart normalization ----
candidates = []
for e in entries:
    name = e.get("name", "")
    url = e.get("url") or e.get("@id") or ""
    nb = normalize_basic(name)
    nd = normalize_doberman(name)

    if (
        "doberman" in nb
        or "doberman" in nd
        or any(t in nb for t in targets)
        or any(t in nd for t in targets)
    ):
        candidates.append((name, url))

# ---- If nothing found with the above, do fuzzy search as fallback ----
if not candidates:
    names = [e.get("name", "") for e in entries if "name" in e]
    norm_names = [normalize_doberman(n) for n in names]
    # fuzzy on normalized strings
    close = get_close_matches("doberman", norm_names, n=5, cutoff=0.6)
    for n in close:
        idx = norm_names.index(n)
        e = entries[idx]
        candidates.append((e.get("name", ""), e.get("url") or e.get("@id") or ""))

# ---- Also scan additionalProperty for synonyms/aliases, just in case ----
if not candidates:
    for e in entries:
        props = e.get("additionalProperty") or []
        for p in props:
            val = p.get("value") or ""
            if isinstance(val, str):
                nb = normalize_basic(val)
                nd = normalize_doberman(val)
                if "doberman" in nb or "doberman" in nd:
                    candidates.append((e.get("name", ""), e.get("url") or e.get("@id") or ""))
                    break

# ---- Print results ----
if candidates:
    print("Possible Doberman entries found:")
    for name, url in candidates:
        print(f" - {name}  ({url})")
else:
    print("No Doberman variants found. Consider opening the JSON and searching for 'dob' / 'pinscher'.")
# Out:
# Possible Doberman entries found:
#  - Doberman Pinscher  (https://pawsomeauthority.com/dog-breeds/doberman-pinscher/profile/)

# %%
import json
import pprint

entries = data.get("mainEntity", [])

# Normalize names to match easily
def normalize(s):
    return s.lower().replace("-", " ").replace("_", " ").strip()

# Find Boxer entry
target_name = "boxer"
boxer_entry = None
for entry in entries:
    if normalize(entry.get("name", "")) == target_name:
        boxer_entry = entry
        break

if boxer_entry:
    print("✅ Boxer entry found. Keys available:")
    pprint.pprint(boxer_entry.keys())
    
    print("\n--- Full entry preview ---")
    pprint.pprint(boxer_entry, depth=2, width=120)
    
    # Optionally print 'additionalProperty' for extra attributes
    if "additionalProperty" in boxer_entry:
        print("\n--- Additional properties ---")
        for prop in boxer_entry["additionalProperty"]:
            pprint.pprint(prop)
else:
    print("Boxer not found in the dataset.")
# Out:
# ✅ Boxer entry found. Keys available:
# dict_keys(['@context', '@type', '@id', 'name', 'url', 'additionalType', 'additionalProperty'])
#
# --- Full entry preview ---
# {'@context': 'https://schema.org/',
#  '@id': 'https://pawsomeauthority.com/dog-breeds/boxer/profile/',
#  '@type': 'Thing',
#  'additionalProperty': [{...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...},
#                         {...}],
#  'additionalType': 'https://schema.org/Animal',
#  'name': 'Boxer',
#  'url': 'https://pawsomeauthority.com/dog-breeds/boxer/profile/'}
#
# --- Additional properties ---
# {'@type': 'PropertyValue', 'name': 'breed', 'value': 'Boxer'}
# {'@type': 'PropertyValue', 'name': 'pronunciation', 'value': 'Bok-ser'}
# {'@type': 'PropertyValue',
#  'name': 'alternateName',
#  'value': 'Deutscher Boxer, German Boxer'}
# {'@type': 'PropertyValue', 'name': 'nickname', 'value': '-'}
# {'@type': 'PropertyValue', 'name': 'countryOfOrigin', 'value': 'Germany'}
# {'@type': 'PropertyValue', 'name': 'category', 'value': 'Working'}
# {'@type': 'PropertyValue', 'name': 'size', 'value': ['Large']}
# {'@type': 'PropertyValue',
#  'name': 'heightMaleInches',
#  'value': {'@type': 'QuantitativeValue',
#            'maxValue': 25,
#            'minValue': 23,
#            'unitCode': 'INH'}}
# {'@type': 'PropertyValue',
#  'name': 'heightMaleCentimeters',
#  'value': {'@type': 'QuantitativeValue',
#            'maxValue': 63.5,
#            'minValue': 58.5,
#            'unitCode': 'CMT'}}
# {'@type': 'PropertyValue',
#  'name': 'heightFemaleInches',
#  'value': {'@type': 'QuantitativeValue',
#            'maxValue': 23.5,
#            'minValue': 21.5,
#            'unitCode': 'INH'}}
# {'@type': 'PropertyValue',
#  'name': 'heightFemaleCentimeters',
#  'value': {'@type': 'QuantitativeValue',
#            'maxValue': 59.5,
#            'minValue': 54.5,
#            'unitCode': 'CMT'}}
# {'@type': 'PropertyValue',
#  'name': 'weightMalePounds',
#  'value': {'@type': 'QuantitativeValue',
#            'maxValue': 80,
#            'minValue': 65,
#            'unitCode': 'LBR'}}
# {'@type': 'PropertyValue',
#  'name': 'weightMaleKilograms',
#  'value': {'@type': 'QuantitativeValue',
#            'maxValue': 36.5,
#            'minValue': 29.5,
#            'unitCode': 'KGM'}}
# {'@type': 'PropertyValue',
#  'name': 'weightFemalePounds',
#  'value': {'@type': 'QuantitativeValue',
#            'maxValue': 65,
#            'minValue': 50,
#            'unitCode': 'LBR'}}
# {'@type': 'PropertyValue',
#  'name': 'weightFemaleKilograms',
#  'value': {'@type': 'QuantitativeValue',
#            'maxValue': 29.5,
#            'minValue': 22.5,
#            'unitCode': 'KGM'}}
# {'@type': 'PropertyValue',
#  'name': 'coatLength',
#  'propertyID': 'physical_characteristics',
#  'value': ['Short']}
# {'@type': 'PropertyValue',
#  'name': 'coatType',
#  'propertyID': 'physical_characteristics',
#  'value': ['Smooth']}
# {'@type': 'PropertyValue',
#  'name': 'doubleCoat',
#  'propertyID': 'physical_characteristics',
#  'value': 'No'}
# {'@type': 'PropertyValue',
#  'name': 'hypoallergenic',
#  'propertyID': 'physical_characteristics',
#  'value': 'No'}
# {'@type': 'PropertyValue',
#  'description': 'Level of bonding with loved ones (scale of 1 to 5)',
#  'name': 'affection',
#  'propertyID': 'personality_temperament',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Eagerness to engage in playful activities (scale of 1 to 5)',
#  'name': 'playfulness',
#  'propertyID': 'personality_temperament',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Instinct to safeguard and defend loved ones (scale of 1 to 5)',
#  'name': 'protectiveness',
#  'propertyID': 'personality_temperament',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Tendency to defend territory or space against intruders '
#                 '(scale of 1 to 5)',
#  'name': 'territoriality',
#  'propertyID': 'personality_temperament',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Instinct to chase and capture prey or moving objects (scale '
#                 'of 1 to 5)',
#  'name': 'preyDrive',
#  'propertyID': 'personality_temperament',
#  'value': 3}
# {'@type': 'PropertyValue',
#  'description': 'Tendency to bark and be vocal (scale of 1 to 5)',
#  'name': 'barking',
#  'propertyID': 'personality_temperament',
#  'value': 3}
# {'@type': 'PropertyValue',
#  'description': 'Compatibility and interaction with children (scale of 1 to 5)',
#  'name': 'withChildren',
#  'propertyID': 'personality_temperament',
#  'value': 5}
# {'@type': 'PropertyValue',
#  'description': 'Compatibility and interaction with adults (scale of 1 to 5)',
#  'name': 'withAdults',
#  'propertyID': 'personality_temperament',
#  'value': 5}
# {'@type': 'PropertyValue',
#  'description': 'Compatibility and interaction with other dogs (scale of 1 to '
#                 '5)',
#  'name': 'withDogs',
#  'propertyID': 'personality_temperament',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Compatibility and interaction with household pets (scale of 1 '
#                 'to 5)',
#  'name': 'withOtherPets',
#  'propertyID': 'personality_temperament',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Compatibility and interaction with unfamiliar faces (scale of '
#                 '1 to 5)',
#  'name': 'withStrangers',
#  'propertyID': 'personality_temperament',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Willingness to seek out and enjoy social interaction (scale '
#                 'of 1 to 5)',
#  'name': 'sociability',
#  'propertyID': 'personality_temperament',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Responsiveness to environmental changes (scale of 1 to 5)',
#  'name': 'sensitivity',
#  'propertyID': 'personality_temperament',
#  'value': 3}
# {'@type': 'PropertyValue',
#  'description': 'Level of distress when separated from loved ones (scale of 1 '
#                 'to 5)',
#  'name': 'separationAnxiety',
#  'propertyID': 'personality_temperament',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Overall energy levels and exercise needs (scale of 1 to 5)',
#  'name': 'energyLevel',
#  'propertyID': 'training_exercise',
#  'value': 5}
# {'@type': 'PropertyValue',
#  'description': 'Ability to learn and solve problems (scale of 1 to 5)',
#  'name': 'intelligence',
#  'propertyID': 'training_exercise',
#  'value': 3}
# {'@type': 'PropertyValue',
#  'description': 'Need for cognitive challenges and activities (scale of 1 to '
#                 '5)',
#  'name': 'mentalStimulationNeeds',
#  'propertyID': 'training_exercise',
#  'value': 5}
# {'@type': 'PropertyValue',
#  'description': 'Willingness to follow commands (scale of 1 to 5)',
#  'name': 'obedience',
#  'propertyID': 'training_exercise',
#  'value': 3}
# {'@type': 'PropertyValue',
#  'description': 'Responsiveness to training techniques (scale of 1 to 5)',
#  'name': 'trainability',
#  'propertyID': 'training_exercise',
#  'value': 3}
# {'@type': 'PropertyValue',
#  'description': 'Tendency to resist direction or assert independence (scale of '
#                 '1 to 5)',
#  'name': 'stubbornness',
#  'propertyID': 'training_exercise',
#  'value': 3}
# {'@type': 'PropertyValue',
#  'description': 'Ability to stay focused during tasks or training (scale of 1 '
#                 'to 5)',
#  'name': 'attentionSpan',
#  'propertyID': 'training_exercise',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Frequency and volume of hair loss (scale of 1 to 5)',
#  'name': 'shedding',
#  'propertyID': 'grooming_maintenance',
#  'value': 2}
# {'@type': 'PropertyValue',
#  'description': 'Coat maintenance requirements (scale of 1 to 5)',
#  'name': 'maintenance',
#  'propertyID': 'grooming_maintenance',
#  'value': 2}
# {'@type': 'PropertyValue',
#  'description': 'Tendency to produce excessive saliva (scale of 1 to 5)',
#  'name': 'drooling',
#  'propertyID': 'grooming_maintenance',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Expected lifespan in years',
#  'name': 'lifespan',
#  'propertyID': 'health_lifespan',
#  'value': {'@type': 'QuantitativeValue',
#            'maxValue': 12,
#            'minValue': 10,
#            'unitCode': 'ANN'}}
# {'@type': 'PropertyValue',
#  'description': 'Predisposition to specific health conditions (scale of 1 to '
#                 '5)',
#  'name': 'overallHealth',
#  'propertyID': 'health_lifespan',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Predisposition to dental issues (scale of 1 to 5)',
#  'name': 'dentalIssues',
#  'propertyID': 'health_lifespan',
#  'value': 3}
# {'@type': 'PropertyValue',
#  'description': 'Predisposition to ear issues (scale of 1 to 5)',
#  'name': 'earIssues',
#  'propertyID': 'health_lifespan',
#  'value': 2}
# {'@type': 'PropertyValue',
#  'description': 'Predisposition to eye issues (scale of 1 to 5)',
#  'name': 'eyeIssues',
#  'propertyID': 'health_lifespan',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Recommended experience level for potential owners (scale of 1 '
#                 'to 5)',
#  'name': 'experienceRequired',
#  'propertyID': 'breed_suitability',
#  'value': 4}
# {'@type': 'PropertyValue',
#  'description': 'Suitability for individuals with no prior dog ownership '
#                 'experience (suitable/not suitable)',
#  'name': 'firstTimeOwnerSuitable',
#  'propertyID': 'breed_suitability',
#  'value': 'Not Suitable'}
# {'@type': 'PropertyValue',
#  'description': 'Suitability for living in small spaces (scale of 1 to 5)',
#  'name': 'apartmentLiving',
#  'propertyID': 'breed_suitability',
#  'value': 2}

# %%
for i, prop in enumerate(boxer_entry["additionalProperty"], 1):
    print(f"{i}: {prop}")
# Out:
# 1: {'@type': 'PropertyValue', 'name': 'breed', 'value': 'Boxer'}
# 2: {'@type': 'PropertyValue', 'name': 'pronunciation', 'value': 'Bok-ser'}
# 3: {'@type': 'PropertyValue', 'name': 'alternateName', 'value': 'Deutscher Boxer, German Boxer'}
# 4: {'@type': 'PropertyValue', 'name': 'nickname', 'value': '-'}
# 5: {'@type': 'PropertyValue', 'name': 'countryOfOrigin', 'value': 'Germany'}
# 6: {'@type': 'PropertyValue', 'name': 'category', 'value': 'Working'}
# 7: {'@type': 'PropertyValue', 'name': 'size', 'value': ['Large']}
# 8: {'@type': 'PropertyValue', 'name': 'heightMaleInches', 'value': {'@type': 'QuantitativeValue', 'minValue': 23, 'maxValue': 25, 'unitCode': 'INH'}}
# 9: {'@type': 'PropertyValue', 'name': 'heightMaleCentimeters', 'value': {'@type': 'QuantitativeValue', 'minValue': 58.5, 'maxValue': 63.5, 'unitCode': 'CMT'}}
# 10: {'@type': 'PropertyValue', 'name': 'heightFemaleInches', 'value': {'@type': 'QuantitativeValue', 'minValue': 21.5, 'maxValue': 23.5, 'unitCode': 'INH'}}
# 11: {'@type': 'PropertyValue', 'name': 'heightFemaleCentimeters', 'value': {'@type': 'QuantitativeValue', 'minValue': 54.5, 'maxValue': 59.5, 'unitCode': 'CMT'}}
# 12: {'@type': 'PropertyValue', 'name': 'weightMalePounds', 'value': {'@type': 'QuantitativeValue', 'minValue': 65, 'maxValue': 80, 'unitCode': 'LBR'}}
# 13: {'@type': 'PropertyValue', 'name': 'weightMaleKilograms', 'value': {'@type': 'QuantitativeValue', 'minValue': 29.5, 'maxValue': 36.5, 'unitCode': 'KGM'}}
# 14: {'@type': 'PropertyValue', 'name': 'weightFemalePounds', 'value': {'@type': 'QuantitativeValue', 'minValue': 50, 'maxValue': 65, 'unitCode': 'LBR'}}
# 15: {'@type': 'PropertyValue', 'name': 'weightFemaleKilograms', 'value': {'@type': 'QuantitativeValue', 'minValue': 22.5, 'maxValue': 29.5, 'unitCode': 'KGM'}}
# 16: {'@type': 'PropertyValue', 'name': 'coatLength', 'value': ['Short'], 'propertyID': 'physical_characteristics'}
# 17: {'@type': 'PropertyValue', 'name': 'coatType', 'value': ['Smooth'], 'propertyID': 'physical_characteristics'}
# 18: {'@type': 'PropertyValue', 'name': 'doubleCoat', 'value': 'No', 'propertyID': 'physical_characteristics'}
# 19: {'@type': 'PropertyValue', 'name': 'hypoallergenic', 'value': 'No', 'propertyID': 'physical_characteristics'}
# 20: {'@type': 'PropertyValue', 'name': 'affection', 'value': 4, 'description': 'Level of bonding with loved ones (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 21: {'@type': 'PropertyValue', 'name': 'playfulness', 'value': 4, 'description': 'Eagerness to engage in playful activities (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 22: {'@type': 'PropertyValue', 'name': 'protectiveness', 'value': 4, 'description': 'Instinct to safeguard and defend loved ones (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 23: {'@type': 'PropertyValue', 'name': 'territoriality', 'value': 4, 'description': 'Tendency to defend territory or space against intruders (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 24: {'@type': 'PropertyValue', 'name': 'preyDrive', 'value': 3, 'description': 'Instinct to chase and capture prey or moving objects (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 25: {'@type': 'PropertyValue', 'name': 'barking', 'value': 3, 'description': 'Tendency to bark and be vocal (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 26: {'@type': 'PropertyValue', 'name': 'withChildren', 'value': 5, 'description': 'Compatibility and interaction with children (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 27: {'@type': 'PropertyValue', 'name': 'withAdults', 'value': 5, 'description': 'Compatibility and interaction with adults (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 28: {'@type': 'PropertyValue', 'name': 'withDogs', 'value': 4, 'description': 'Compatibility and interaction with other dogs (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 29: {'@type': 'PropertyValue', 'name': 'withOtherPets', 'value': 4, 'description': 'Compatibility and interaction with household pets (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 30: {'@type': 'PropertyValue', 'name': 'withStrangers', 'value': 4, 'description': 'Compatibility and interaction with unfamiliar faces (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 31: {'@type': 'PropertyValue', 'name': 'sociability', 'value': 4, 'description': 'Willingness to seek out and enjoy social interaction (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 32: {'@type': 'PropertyValue', 'name': 'sensitivity', 'value': 3, 'description': 'Responsiveness to environmental changes (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 33: {'@type': 'PropertyValue', 'name': 'separationAnxiety', 'value': 4, 'description': 'Level of distress when separated from loved ones (scale of 1 to 5)', 'propertyID': 'personality_temperament'}
# 34: {'@type': 'PropertyValue', 'name': 'energyLevel', 'value': 5, 'description': 'Overall energy levels and exercise needs (scale of 1 to 5)', 'propertyID': 'training_exercise'}
# 35: {'@type': 'PropertyValue', 'name': 'intelligence', 'value': 3, 'description': 'Ability to learn and solve problems (scale of 1 to 5)', 'propertyID': 'training_exercise'}
# 36: {'@type': 'PropertyValue', 'name': 'mentalStimulationNeeds', 'value': 5, 'description': 'Need for cognitive challenges and activities (scale of 1 to 5)', 'propertyID': 'training_exercise'}
# 37: {'@type': 'PropertyValue', 'name': 'obedience', 'value': 3, 'description': 'Willingness to follow commands (scale of 1 to 5)', 'propertyID': 'training_exercise'}
# 38: {'@type': 'PropertyValue', 'name': 'trainability', 'value': 3, 'description': 'Responsiveness to training techniques (scale of 1 to 5)', 'propertyID': 'training_exercise'}
# 39: {'@type': 'PropertyValue', 'name': 'stubbornness', 'value': 3, 'description': 'Tendency to resist direction or assert independence (scale of 1 to 5)', 'propertyID': 'training_exercise'}
# 40: {'@type': 'PropertyValue', 'name': 'attentionSpan', 'value': 4, 'description': 'Ability to stay focused during tasks or training (scale of 1 to 5)', 'propertyID': 'training_exercise'}
# 41: {'@type': 'PropertyValue', 'name': 'shedding', 'value': 2, 'description': 'Frequency and volume of hair loss (scale of 1 to 5)', 'propertyID': 'grooming_maintenance'}
# 42: {'@type': 'PropertyValue', 'name': 'maintenance', 'value': 2, 'description': 'Coat maintenance requirements (scale of 1 to 5)', 'propertyID': 'grooming_maintenance'}
# 43: {'@type': 'PropertyValue', 'name': 'drooling', 'value': 4, 'description': 'Tendency to produce excessive saliva (scale of 1 to 5)', 'propertyID': 'grooming_maintenance'}
# 44: {'@type': 'PropertyValue', 'name': 'lifespan', 'value': {'@type': 'QuantitativeValue', 'minValue': 10, 'maxValue': 12, 'unitCode': 'ANN'}, 'description': 'Expected lifespan in years', 'propertyID': 'health_lifespan'}
# 45: {'@type': 'PropertyValue', 'name': 'overallHealth', 'value': 4, 'description': 'Predisposition to specific health conditions (scale of 1 to 5)', 'propertyID': 'health_lifespan'}
# 46: {'@type': 'PropertyValue', 'name': 'dentalIssues', 'value': 3, 'description': 'Predisposition to dental issues (scale of 1 to 5)', 'propertyID': 'health_lifespan'}
# 47: {'@type': 'PropertyValue', 'name': 'earIssues', 'value': 2, 'description': 'Predisposition to ear issues (scale of 1 to 5)', 'propertyID': 'health_lifespan'}
# 48: {'@type': 'PropertyValue', 'name': 'eyeIssues', 'value': 4, 'description': 'Predisposition to eye issues (scale of 1 to 5)', 'propertyID': 'health_lifespan'}
# 49: {'@type': 'PropertyValue', 'name': 'experienceRequired', 'value': 4, 'description': 'Recommended experience level for potential owners (scale of 1 to 5)', 'propertyID': 'breed_suitability'}
# 50: {'@type': 'PropertyValue', 'name': 'firstTimeOwnerSuitable', 'value': 'Not Suitable', 'description': 'Suitability for individuals with no prior dog ownership experience (suitable/not suitable)', 'propertyID': 'breed_suitability'}
# 51: {'@type': 'PropertyValue', 'name': 'apartmentLiving', 'value': 2, 'description': 'Suitability for living in small spaces (scale of 1 to 5)', 'propertyID': 'breed_suitability'}
